# %%
import pandas as pd

# %% [markdown]
# ## Let's take a look at the data

# %%
matches=pd.read_csv('matches.csv')

# %%
matches.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %% [markdown]
# ### Rename columns

# %%
matches.rename(columns={'player_of_match':'man_of_match'},inplace=True)

# %%
matches.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
matches.rename(columns={'man_of_match':'player_of_match', 'venue':'stadium'},inplace=True)

# %%
matches.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %% [markdown]
# ## Sorting

# %%
matches['win_by_runs'].sort_values(ascending=False)
# Out:
# 43     146
# 619    144
# 59     140
# 556    138
# 410    130
#       ...
# 283      0
# 460      0
# 285      0
# 662      0
# 278      0
# Name: win_by_runs, Length: 756, dtype: int64

# %%
matches.sort_values('win_by_runs',ascending=False)
# Out:
#       id  season       city        date                        team1  \
# 43    44    2017      Delhi  2017-05-06               Mumbai Indians
# 619  620    2016  Bangalore  2016-05-14  Royal Challengers Bangalore
# 59    60    2008  Bangalore  2008-04-18        Kolkata Knight Riders
# 556  557    2015  Bangalore  2015-05-06  Royal Challengers Bangalore
# 410  411    2013  Bangalore  2013-04-23  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 56    57    2017  Bangalore  2017-05-17          Sunrisers Hyderabad
# 363  364    2012    Chennai  2012-05-12             Delhi Daredevils
# 57    58    2017  Bangalore  2017-05-19        Kolkata Knight Riders
# 360  361    2012     Jaipur  2012-05-10             Rajasthan Royals
# 46    47    2017  Hyderabad  2017-05-08               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
matches.sort_values(['season','city','team1','team2'],ascending=False)
# Out:
#         id  season           city        date                        team1  \
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 726  11322    2019         Mumbai    15/04/19  Royal Challengers Bangalore
# 746  11342    2019         Mumbai    02/05/19               Mumbai Indians
# 722  11318    2019         Mumbai    13/04/19               Mumbai Indians
# ..     ...     ...            ...         ...                          ...
# 83      84    2008      Bangalore  2008-05-05  Royal Challengers Bangalore
# 103    104    2008      Bangalore  2008-05-19  Royal Challengers Bangalore
# 110    111    2008      Bangalore  2008-05-03  Royal Challengers Bangalore
# 59      60    2008      Bangalore  2008-04-18        Kolkata Knight Riders
# 73      74    2008      Bangalore  2008-04-28          Chennai Super Kings
#
# ...
