# %% [markdown]
# # How do we read data in Pandas?

# %%
import pandas as pd

# %% [markdown]
# ### Reading Local Dataset

# %%
pd.read_csv('titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.read_csv('data/food.csv')
# Out:
#          Name Gender     City Frequency      Item  Spends
# 0      Nitish      M  Kolkata    Weekly    Burger      11
# 1         Anu      F  Gurgaon     Daily  Sandwich      14
# 2       Mukku      M  Kolkata      Once      Vada      25
# 3        Suri      M  Kolkata   Monthly     Pizza      56
# 4       Rajiv      M    Patna     Never    Paneer      34
# 5    Vandanda      F    Patna      Once   Chicken      23
# 6      Piyush      M   Ranchi     Never   Chicken      67
# 7     Radhika      F   Mumbai   Monthly     Pizza      43
# 8       Sunil      M   Mumbai   Monthly      Vada      34
# 9     Madhuri      F     Pune     Daily    Paneer      66
# 10      Sonal      F     Pune   Monthly     Pizza      89
# 11      Abhay      M    Patna     Daily    Burger      65
# 12     Vineet      M   Ranchi      Once  Sandwich      34
# 13      Sumit      M  Gurgaon     Never  Sandwich      34
# 14     Ranbir      M   Mumbai    Weekly      Vada      55
# ...

# %% [markdown]
# ### Reading Data from Url

# %%
pd.read_csv('http://bit.ly/uforeports')
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %% [markdown]
# ### Reading data without Headers

# %%
columns=['Name','Gender','City','Frequency','Item','Spends']

# %%
pd.read_csv('food1.csv',header=None,names=columns)
# Out:
#          Name Gender     City Frequency      Item  Spends
# 0      Nitish      M  Kolkata    Weekly    Burger      11
# 1         Anu      F  Gurgaon     Daily  Sandwich      14
# 2       Mukku      M  Kolkata      Once      Vada      25
# 3        Suri      M  Kolkata   Monthly     Pizza      56
# 4       Rajiv      M    Patna     Never    Paneer      34
# 5    Vandanda      F    Patna      Once   Chicken      23
# 6      Piyush      M   Ranchi     Never   Chicken      67
# 7     Radhika      F   Mumbai   Monthly     Pizza      43
# 8       Sunil      M   Mumbai   Monthly      Vada      34
# 9     Madhuri      F     Pune     Daily    Paneer      66
# 10      Sonal      F     Pune   Monthly     Pizza      89
# 11      Abhay      M    Patna     Daily    Burger      65
# 12     Vineet      M   Ranchi      Once  Sandwich      34
# 13      Sumit      M  Gurgaon     Never  Sandwich      34
# 14     Ranbir      M   Mumbai    Weekly      Vada      55
# ...

# %% [markdown]
# ### Reading Data with different separators

# %%
columns=['user_id','age','gender','occupation','zip_codes']

# %%
pd.read_csv('http://bit.ly/movieusers',sep='|',header=None,names=columns)
# Out:
#      user_id  age gender     occupation zip_codes
# 0          1   24      M     technician     85711
# 1          2   53      F          other     94043
# 2          3   23      M         writer     32067
# 3          4   24      M     technician     43537
# 4          5   33      F          other     15213
# ..       ...  ...    ...            ...       ...
# 938      939   26      F        student     33319
# 939      940   32      M  administrator     02215
# 940      941   20      M        student     97229
# 941      942   48      F      librarian     78209
# 942      943   22      M        student     77841
#
# [943 rows x 5 columns]
