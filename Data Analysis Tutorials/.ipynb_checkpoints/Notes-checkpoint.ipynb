# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
titanic=pd.read_csv('titanic_train.csv')

# %% [markdown]
# # Does being a female increase your chances of survival in the Disaster?

# %%
titanic[:60]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# 26           27         0       3
# 27           28         0       1
# 28           29         1       3
# 29           30         0       3
# 30           31         0       1
# 31           32         1       1
# 32           33         1       3
# 33           34         0       2
# 34           35         0       1
# 35           36         0       1
# 36           37         1       3
# 37           38         0       3
# 38           39         0       3
# 39           40         1       3
# 40           41         0       3
# 41           42         0       2
# 42           43         0       3
# 43           44         1       2
# 44           45         1       3
# 45           46         0       3
# 46           47         0       3
# 47           48         1       3
# 48           49         0       3
# 49           50         0       3
# 50           51         0       3
# 51           52         0       3
# 52           53         1       1
# 53           54         1       2
# 54           55         0       1
# 55           56         1       1
# 56           57         1       2
# 57           58         0       3
# 58           59         1       2
# 59           60         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                               Rice, Master. Eugene    male   2.0      4
# 17                       Williams, Mr. Charles Eugene    male   NaN      0
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                            Masselmani, Mrs. Fatima  female   NaN      0
# 20                               Fynney, Mr. Joseph J    male  35.0      0
# 21                              Beesley, Mr. Lawrence    male  34.0      0
# 22                        McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                       Sloper, Mr. William Thompson    male  28.0      0
# 24                      Palsson, Miss. Torborg Danira  female   8.0      3
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 26                            Emir, Mr. Farred Chehab    male   NaN      0
# 27                     Fortune, Mr. Charles Alexander    male  19.0      3
# 28                      O'Dwyer, Miss. Ellen "Nellie"  female   NaN      0
# 29                                Todoroff, Mr. Lalio    male   NaN      0
# 30                           Uruchurtu, Don. Manuel E    male  40.0      0
# 31     Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 32                           Glynn, Miss. Mary Agatha  female   NaN      0
# 33                              Wheadon, Mr. Edward H    male  66.0      0
# 34                            Meyer, Mr. Edgar Joseph    male  28.0      1
# 35                     Holverson, Mr. Alexander Oskar    male  42.0      1
# 36                                   Mamee, Mr. Hanna    male   NaN      0
# 37                           Cann, Mr. Ernest Charles    male  21.0      0
# 38                 Vander Planke, Miss. Augusta Maria  female  18.0      2
# 39                        Nicola-Yarred, Miss. Jamila  female  14.0      1
# 40     Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# 41  Turpin, Mrs. William John Robert (Dorothy Ann ...  female  27.0      1
# 42                                Kraeff, Mr. Theodor    male   NaN      0
# 43           Laroche, Miss. Simonne Marie Anne Andree  female   3.0      1
# 44                      Devaney, Miss. Margaret Delia  female  19.0      0
# 45                           Rogers, Mr. William John    male   NaN      0
# 46                                  Lennon, Mr. Denis    male   NaN      1
# 47                          O'Driscoll, Miss. Bridget  female   NaN      0
# 48                                Samaan, Mr. Youssef    male   NaN      2
# 49      Arnold-Franchi, Mrs. Josef (Josefine Franchi)  female  18.0      1
# 50                         Panula, Master. Juha Niilo    male   7.0      4
# 51                       Nosworthy, Mr. Richard Cater    male  21.0      0
# 52           Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# 53  Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkin...  female  29.0      1
# 54                     Ostby, Mr. Engelhart Cornelius    male  65.0      0
# 55                                  Woolner, Mr. Hugh    male   NaN      0
# 56                                  Rugg, Miss. Emily  female  21.0      0
# 57                                Novel, Mr. Mansouer    male  28.5      0
# 58                       West, Miss. Constance Mirium  female   5.0      1
# 59                 Goodwin, Master. William Frederick    male  11.0      5
#
#     Parch            Ticket      Fare        Cabin Embarked
# 0       0         A/5 21171    7.2500          NaN        S
# 1       0          PC 17599   71.2833          C85        C
# 2       0  STON/O2. 3101282    7.9250          NaN        S
# 3       0            113803   53.1000         C123        S
# 4       0            373450    8.0500          NaN        S
# 5       0            330877    8.4583          NaN        Q
# 6       0             17463   51.8625          E46        S
# 7       1            349909   21.0750          NaN        S
# 8       2            347742   11.1333          NaN        S
# 9       0            237736   30.0708          NaN        C
# 10      1           PP 9549   16.7000           G6        S
# 11      0            113783   26.5500         C103        S
# 12      0         A/5. 2151    8.0500          NaN        S
# 13      5            347082   31.2750          NaN        S
# 14      0            350406    7.8542          NaN        S
# 15      0            248706   16.0000          NaN        S
# 16      1            382652   29.1250          NaN        Q
# 17      0            244373   13.0000          NaN        S
# 18      0            345763   18.0000          NaN        S
# 19      0              2649    7.2250          NaN        C
# 20      0            239865   26.0000          NaN        S
# 21      0            248698   13.0000          D56        S
# 22      0            330923    8.0292          NaN        Q
# 23      0            113788   35.5000           A6        S
# 24      1            349909   21.0750          NaN        S
# 25      5            347077   31.3875          NaN        S
# 26      0              2631    7.2250          NaN        C
# 27      2             19950  263.0000  C23 C25 C27        S
# 28      0            330959    7.8792          NaN        Q
# 29      0            349216    7.8958          NaN        S
# 30      0          PC 17601   27.7208          NaN        C
# 31      0          PC 17569  146.5208          B78        C
# 32      0            335677    7.7500          NaN        Q
# 33      0        C.A. 24579   10.5000          NaN        S
# 34      0          PC 17604   82.1708          NaN        C
# 35      0            113789   52.0000          NaN        S
# 36      0              2677    7.2292          NaN        C
# 37      0        A./5. 2152    8.0500          NaN        S
# 38      0            345764   18.0000          NaN        S
# 39      0              2651   11.2417          NaN        C
# 40      0              7546    9.4750          NaN        S
# 41      0             11668   21.0000          NaN        S
# 42      0            349253    7.8958          NaN        C
# 43      2     SC/Paris 2123   41.5792          NaN        C
# 44      0            330958    7.8792          NaN        Q
# 45      0   S.C./A.4. 23567    8.0500          NaN        S
# 46      0            370371   15.5000          NaN        Q
# 47      0             14311    7.7500          NaN        Q
# 48      0              2662   21.6792          NaN        C
# 49      0            349237   17.8000          NaN        S
# 50      1           3101295   39.6875          NaN        S
# 51      0        A/4. 39886    7.8000          NaN        S
# 52      0          PC 17572   76.7292          D33        C
# 53      0              2926   26.0000          NaN        S
# 54      1            113509   61.9792          B30        C
# 55      0             19947   35.5000          C52        S
# 56      0        C.A. 31026   10.5000          NaN        S
# 57      0              2697    7.2292          NaN        C
# 58      2        C.A. 34651   27.7500          NaN        S
# 59      2           CA 2144   46.9000          NaN        S

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                      Name   Sex  \
# count    891.000000  891.000000  891.000000                       891   891
# unique          NaN         NaN         NaN                       891     2
# top             NaN         NaN         NaN  Taylor, Mr. Elmer Zebley  male
# freq            NaN         NaN         NaN                         1   577
# mean     446.000000    0.383838    2.308642                       NaN   NaN
# std      257.353842    0.486592    0.836071                       NaN   NaN
# min        1.000000    0.000000    1.000000                       NaN   NaN
# 25%      223.500000    0.000000    2.000000                       NaN   NaN
# 50%      446.000000    0.000000    3.000000                       NaN   NaN
# 75%      668.500000    1.000000    3.000000                       NaN   NaN
# max      891.000000    1.000000    3.000000                       NaN   NaN
#
#                Age       SibSp       Parch    Ticket        Fare Cabin  \
# count   714.000000  891.000000  891.000000       891  891.000000   204
# unique         NaN         NaN         NaN       681         NaN   147
# top            NaN         NaN         NaN  CA. 2343         NaN    G6
# freq           NaN         NaN         NaN         7         NaN     4
# mean     29.699118    0.523008    0.381594       NaN   32.204208   NaN
# std      14.526497    1.102743    0.806057       NaN   49.693429   NaN
# min       0.420000    0.000000    0.000000       NaN    0.000000   NaN
# 25%      20.125000    0.000000    0.000000       NaN    7.910400   NaN
# 50%      28.000000    0.000000    0.000000       NaN   14.454200   NaN
# 75%      38.000000    1.000000    0.000000       NaN   31.000000   NaN
# max      80.000000    8.000000    6.000000       NaN  512.329200   NaN
#
#        Embarked
# count       889
# unique        3
# top           S
# freq        644
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %% [markdown]
# ## Quality
#
# - Cabin column has many null values `Solved`
# - Embarked has 2 missing values `Solved`
# - Age has many missing values `Solved`
# - Age has values less than 1 `Solved`
# - Age is represented in float `Solved`
# - Survived, Pclass is in integer `Solved`
# - Sex is in object `Solved`
# - SibSp and Parch can be merged into one column called Family `Solved`
# - No consistency in Ticket `Solved`
#
# #### Be sure to make a backup copy

# %%
titanic_backup=titanic.copy()

# %%
titanic=titanic_backup.copy()

# %% [markdown]
# ### Cleaning

# %% [markdown]
# #### Issue: Cabin column has many null values
#
# `Solution`: Drop cabin column
#
# #### Code

# %%
titanic.drop(columns='Cabin',inplace=True)

# %% [markdown]
# #### Test

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Embarked
# 0        0         A/5 21171   7.2500        S
# 1        0          PC 17599  71.2833        C
# 2        0  STON/O2. 3101282   7.9250        S
# 3        0            113803  53.1000        S
# 4        0            373450   8.0500        S
# ..     ...               ...      ...      ...
# 886      0            211536  13.0000        S
# 887      0            112053  30.0000        S
# 888      2        W./C. 6607  23.4500        S
# 889      0            111369  30.0000        C
# 890      0            370376   7.7500        Q
#
# [891 rows x 11 columns]

# %% [markdown]
# #### Issue: Embarked has 2 missing values
#
# `Solution`: Replace missing values by City 'S'

# %%
titanic['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
titanic[titanic['Embarked'].isna()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Embarked
# 61   female  38.0      0      0  113572  80.0      NaN
# 829  female  62.0      0      0  113572  80.0      NaN

# %% [markdown]
# #### Code

# %%
titanic['Embarked']=titanic['Embarked'].fillna('S')

# %% [markdown]
# #### Test

# %%
titanic['Embarked'].isna().sum()
# Out:
# 0

# %% [markdown]
# #### Issue: Age has many missing values
# `Solution`: Replace with the mean values of the Designations

# %% [markdown]
# #### Code

# %%
def extract_designation(name):
    
    if 'Mr.' in name:
        return 'Mr'
    elif 'Mrs.' in name:
        return 'Mrs'
    elif 'Miss.' in name:
        return 'Miss'
    elif 'Master.' in name:
        return 'Master'
    return 'Mr'

# %%
titanic['Designation']=titanic['Name'].apply(extract_designation)

# %%
titanic['Designation'].value_counts()
# Out:
# Mr        544
# Miss      182
# Mrs       125
# Master     40
# Name: Designation, dtype: int64

# %%
age_fill_values=titanic.groupby('Designation').mean()['Age']

# %%
age_fill_values
# Out:
# Designation
# Master     4.574167
# Miss      21.773973
# Mr        32.982311
# Mrs       35.898148
# Name: Age, dtype: float64

# %%
x1=titanic[titanic['Designation']=='Mr']
x2=titanic[titanic['Designation']=='Mrs']
x3=titanic[titanic['Designation']=='Miss']
x4=titanic[titanic['Designation']=='Master']

# %%
x1.fillna(value={'Age': age_fill_values['Mr']},inplace=True)
x2.fillna(value={'Age': age_fill_values['Mrs']},inplace=True)
x3.fillna(value={'Age': age_fill_values['Miss']},inplace=True)
x4.fillna(value={'Age': age_fill_values['Master']},inplace=True)
# Out:
# C:\Users\The WonderlanD\Anaconda3\lib\site-packages\pandas\core\generic.py:6287: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
new_titanic=x1.append([x2,x3,x4],ignore_index=True).sort_values('PassengerId')

# %% [markdown]
# #### Test

# %%
new_titanic.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# Designation    0
# dtype: int64

# %% [markdown]
# #### Issue: Age has values less than 1
# `Solution`: Replace by 1

# %% [markdown]
# #### Code

# %%
new_titanic['Age']=np.where(new_titanic['Age']<1,1,new_titanic['Age'])

# %% [markdown]
# #### Test

# %%
new_titanic[new_titanic['Age']<1]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Embarked, Designation]
# Index: []

# %% [markdown]
# #### Issue: Age is represented in float
# `Solution`: Convert into integer

# %%
new_titanic['Age']=new_titanic['Age'].astype(int)

# %%
new_titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 543
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            891 non-null int32
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Embarked       891 non-null object
# Designation    891 non-null object
# dtypes: float64(1), int32(1), int64(5), object(5)
# memory usage: 87.0+ KB

# %% [markdown]
# #### Issue: Survived, Pclass is in integer
#
# `Solution`: Convert into category

# %%
new_titanic['Survived']=new_titanic['Survived'].astype('category')
new_titanic['Pclass']=new_titanic['Pclass'].astype('category')

# %%
new_titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 543
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null category
# Pclass         891 non-null category
# Name           891 non-null object
# Sex            891 non-null object
# Age            891 non-null int32
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Embarked       891 non-null object
# Designation    891 non-null object
# dtypes: category(2), float64(1), int32(1), int64(3), object(5)
# memory usage: 75.0+ KB

# %% [markdown]
# #### Issue: Sex is in object
# `Solution`: Convert into category

# %%
new_titanic['Sex']=new_titanic['Sex'].astype('category')

# %% [markdown]
# #### Issue: SibSp and Parch can be merged into one column called Family

# %%
new_titanic['Family']=new_titanic['SibSp']+new_titanic['Parch']

# %%
new_titanic.drop(columns=['SibSp','Parch'],inplace=True)

# %%
new_titanic['Family'].unique()
# Out:
# array([ 1,  0,  4,  2,  6,  5,  3,  7, 10], dtype=int64)

# %% [markdown]
# #### Issue: No consistency in Ticket
# `Solution`: Drop

# %%
new_titanic.drop(columns=['Ticket','PassengerId'],inplace=True)

# %%
new_titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 543
# Data columns (total 9 columns):
# Survived       891 non-null category
# Pclass         891 non-null category
# Name           891 non-null object
# Sex            891 non-null category
# Age            891 non-null int32
# Fare           891 non-null float64
# Embarked       891 non-null object
# Designation    891 non-null object
# Family         891 non-null int64
# dtypes: category(3), float64(1), int32(1), int64(1), object(3)
# memory usage: 48.1+ KB

# %% [markdown]
# #### Convert Embarked, Designation and Family to category

# %%
new_titanic['Embarked']=new_titanic['Embarked'].astype('category')
new_titanic['Designation']=new_titanic['Designation'].astype('category')
new_titanic['Family']=new_titanic['Family'].astype('category')

# %%
new_titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 543
# Data columns (total 9 columns):
# Survived       891 non-null category
# Pclass         891 non-null category
# Name           891 non-null object
# Sex            891 non-null category
# Age            891 non-null int32
# Fare           891 non-null float64
# Embarked       891 non-null category
# Designation    891 non-null category
# Family         891 non-null category
# dtypes: category(6), float64(1), int32(1), object(1)
# memory usage: 30.5+ KB

# %% [markdown]
# ## Cleaned data

# %%
new_titanic
# Out:
#     Survived Pclass                                               Name  \
# 0          0      3                            Braund, Mr. Owen Harris
# 544        1      1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 669        1      3                             Heikkinen, Miss. Laina
# 545        1      1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 1          0      3                           Allen, Mr. William Henry
# ..       ...    ...                                                ...
# 541        0      2                              Montvila, Rev. Juozas
# 849        1      1                       Graham, Miss. Margaret Edith
# 850        0      3           Johnston, Miss. Catherine Helen "Carrie"
# 542        1      1                              Behr, Mr. Karl Howell
# 543        0      3                                Dooley, Mr. Patrick
#
#         Sex  Age     Fare Embarked Designation Family
# 0      male   22   7.2500        S          Mr      1
# 544  female   38  71.2833        C         Mrs      1
# 669  female   26   7.9250        S        Miss      0
# 545  female   35  53.1000        S         Mrs      1
# 1      male   35   8.0500        S          Mr      0
# ..      ...  ...      ...      ...         ...    ...
# 541    male   27  13.0000        S          Mr      0
# 849  female   19  30.0000        S        Miss      0
# 850  female   21  23.4500        S        Miss      3
# 542    male   26  30.0000        C          Mr      0
# 543    male   32   7.7500        Q          Mr      0
#
# [891 rows x 9 columns]

# %% [markdown]
# # Exploratory Data Analysis
#
#
# #### - Out of the 891 people info. that we have, lets see how many of them really survived
# #### - survival count based on Gender
# #### - survival count of Males and Females and compare it to non-survivors
# #### - analysis based on percentage survived?
# #### - survival percentage of different Classes of people
# #### - survival probability based on Age
# #### - survival probability based on Fare
# #### - Percentage of Children survived
# #### - Probability based on Family size

# %% [markdown]
# ### Out of the 891 people info. that we have, lets see how many of them really survived

# %%
new_titanic['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# ### Let's see the survival count based on Gender

# %%
survived=new_titanic[new_titanic['Survived']==1]

# %%
survived
# Out:
#     Survived Pclass                                               Name  \
# 544        1      1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 669        1      3                             Heikkinen, Miss. Laina
# 545        1      1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 546        1      3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 547        1      2                Nasser, Mrs. Nicholas (Adele Achem)
# ..       ...    ...                                                ...
# 847        1      3                   Najib, Miss. Adele Kiamie "Jane"
# 666        1      1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 667        1      2       Shelley, Mrs. William (Imanita Parrish Hall)
# 849        1      1                       Graham, Miss. Margaret Edith
# 542        1      1                              Behr, Mr. Karl Howell
#
#         Sex  Age     Fare Embarked Designation Family
# 544  female   38  71.2833        C         Mrs      1
# 669  female   26   7.9250        S        Miss      0
# 545  female   35  53.1000        S         Mrs      1
# 546  female   27  11.1333        S         Mrs      2
# 547  female   14  30.0708        C         Mrs      1
# ..      ...  ...      ...      ...         ...    ...
# 847  female   15   7.2250        C        Miss      0
# 666  female   56  83.1583        C         Mrs      1
# 667  female   25  26.0000        S         Mrs      1
# 849  female   19  30.0000        S        Miss      0
# 542    male   26  30.0000        C          Mr      0
#
# [342 rows x 9 columns]

# %%
survived['Sex'].value_counts().plot(kind='pie',autopct='%.2f%%')
plt.title('Survival count based on Gender')
plt.show()

# %% [markdown]
# ### Let's survival count of Males and Females and compare it to non-survivors

# %%
male_female=new_titanic.groupby(['Survived','Sex'],as_index=False)['Name'].agg('count')

# %%
sns.barplot(x='Sex', y='Name', hue='Survived', data=male_female)
plt.title('Survival Comparison based on Gender')
plt.ylabel('No of People')
plt.show()

# %% [markdown]
# ### But these are hard numbers. What if we could do an analysis based on percentage survived?

# %%
new_titanic[new_titanic['Sex']=='female']['Survived'].value_counts().plot(kind='pie',autopct='%.2f%%')
plt.title('Female Survival Percentage')
plt.show()

# %% [markdown]
# 74% of the females survived where the others died

# %%
new_titanic[new_titanic['Sex']=='male']['Survived'].value_counts().plot(kind='pie',autopct='%.2f%%')
plt.title('Male Survival Percentage')
plt.show()

# %% [markdown]
# ### Survival comparison of different Classes of people

# %%
pclass=new_titanic.groupby(['Pclass','Survived'],as_index=False)['Name'].agg('count')

# %%
pclass
# Out:
#   Pclass Survived  Name
# 0      1        0    80
# 1      1        1   136
# 2      2        0    97
# 3      2        1    87
# 4      3        0   372
# 5      3        1   119

# %%
sns.barplot(x='Pclass',y='Name',data=pclass,hue='Survived')
plt.title('Survival Comparison based on Passenger Class')
plt.ylabel('No. of people')
plt.show()

# %% [markdown]
# ### Survival probability based on Age

# %%
plt.hist(x='Age',data=new_titanic[new_titanic['Survived']==1],alpha=0.5,label='Survived',density=True)
plt.hist(x='Age',data=new_titanic[new_titanic['Survived']==0],alpha=0.5,label='Not Survived',density=True)
plt.legend()

# %%
plt.subplots(figsize=(15,5))
sns.distplot(new_titanic[new_titanic['Survived']==1]['Age'],label='Survived')
sns.distplot(new_titanic[new_titanic['Survived']==0]['Age'],label='Not Survived')
plt.legend()
plt.title('Survival Probability based on Age')
plt.show()

# %% [markdown]
# ### Survival probability based on Fare

# %%
plt.subplots(figsize=(15,7))
sns.distplot(new_titanic[new_titanic['Survived']==1]['Fare'],label='Survived')
sns.distplot(new_titanic[new_titanic['Survived']==0]['Fare'],label='Not Survived')
plt.legend()

# %% [markdown]
# ### Percentage of Children survived

# %%
new_titanic[new_titanic['Designation']=='Master']['Survived'].value_counts().plot(kind='pie',autopct='%.2f%%')
plt.title('Percentage of Children survived')
plt.show()

# %% [markdown]
# ### Probability based on Family size

# %%
new_titanic['Family'].unique()
# Out:
# [1, 0, 4, 2, 6, 5, 3, 7, 10]
# Categories (9, int64): [1, 0, 4, 2, ..., 5, 3, 7, 10]

# %%
sns.countplot(x='Family',data=new_titanic,hue='Survived')
plt.title('Probability based on Family Size')
plt.xlabel('Family Size')
plt.show()

# %%
new_titanic
# Out:
#     Survived Pclass                                               Name  \
# 0          0      3                            Braund, Mr. Owen Harris
# 544        1      1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 669        1      3                             Heikkinen, Miss. Laina
# 545        1      1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 1          0      3                           Allen, Mr. William Henry
# ..       ...    ...                                                ...
# 541        0      2                              Montvila, Rev. Juozas
# 849        1      1                       Graham, Miss. Margaret Edith
# 850        0      3           Johnston, Miss. Catherine Helen "Carrie"
# 542        1      1                              Behr, Mr. Karl Howell
# 543        0      3                                Dooley, Mr. Patrick
#
#         Sex  Age     Fare Embarked Designation Family
# 0      male   22   7.2500        S          Mr      1
# 544  female   38  71.2833        C         Mrs      1
# 669  female   26   7.9250        S        Miss      0
# 545  female   35  53.1000        S         Mrs      1
# 1      male   35   8.0500        S          Mr      0
# ..      ...  ...      ...      ...         ...    ...
# 541    male   27  13.0000        S          Mr      0
# 849  female   19  30.0000        S        Miss      0
# 850  female   21  23.4500        S        Miss      3
# 542    male   26  30.0000        C          Mr      0
# 543    male   32   7.7500        Q          Mr      0
#
# [891 rows x 9 columns]

# %% [markdown]
# ## Conclusion
#
# #### - Women and Children were given utmost importance
# #### - Almost 70% of the survivors were females
# #### - Out of all females only 74 % survived and out of all males only 19% survived.
# #### - Passengers from Class 1 and who paid high fairs were given the utmost priority
# #### - Out of all children only  57% survived.
# #### - Passengers with family members 1 to 3 had more chances of survival
